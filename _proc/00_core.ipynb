# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(read_gist)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### read_gist
#
# >      read_gist (user, s)

# %%
#| echo: false
#| output: asis
show_doc(nbclassic_server)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### nbclassic_server
#
# >      nbclassic_server ()

# %%
#| echo: false
#| output: asis
show_doc(docker)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### docker
#
# >      docker ()

# %%
#| echo: false
#| output: asis
show_doc(fasthtml)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### fasthtml
#
# >      fasthtml ()

# %%
#| echo: false
#| output: asis
show_doc(fastcore)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### fastcore
#
# >      fastcore ()

# %%
#| echo: false
#| output: asis
show_doc(claudette)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### claudette
#
# >      claudette ()

# %%
#| echo: false
#| output: asis
show_doc(discord)
# Out:
# ---
#
# [source](https://github.com/AnswerDotAI/ContextKit/blob/main/ContextKit/core.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### discord
#
# >      discord ()
